# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
y = np.array([2.6,3.1,4.3,6.5,8.4,11.2])
x = np.array([0,3,5,8,10,13])

# %%
plt.scatter(x,y,s=50)
plt.plot(x,y)
plt.show()
