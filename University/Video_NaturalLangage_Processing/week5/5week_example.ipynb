# %%
# colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.optimizers import Adam

(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()
x_train = x_train.reshape(60000, 28, 28, 1)
x_test = x_test.reshape(10000, 28, 28, 1)
x_train = x_train.astype(np.float32) / 255.0
x_test = x_test.astype(np.float32) / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

cnn = Sequential()
cnn.add(Conv2D(6, (5, 5), padding='same', activation='relu', input_shape=(28, 28, 1)))
cnn.add(MaxPooling2D(pool_size=(2, 2), strides=2))
cnn.add(Conv2D(16, (5, 5), padding='valid', activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2), strides=2))
cnn.add(Conv2D(120, (5, 5), padding='valid', activation='relu'))
cnn.add(Flatten())
cnn.add(Dense(84, activation='relu'))
cnn.add(Dense(units=10, activation='softmax'))

cnn.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
cnn.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test), verbose=2)

res = cnn.evaluate(x_test, y_test, verbose=0)
print('정확률=', res[1] * 100)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 - 8s - 18ms/step - accuracy: 0.9025 - loss: 0.3150 - val_accuracy: 0.9729 - val_loss: 0.0868
# Epoch 2/10
# 469/469 - 2s - 4ms/step - accuracy: 0.9739 - loss: 0.0844 - val_accuracy: 0.9824 - val_loss: 0.0529
# Epoch 3/10
# 469/469 - 2s - 5ms/step - accuracy: 0.9804 - loss: 0.0629 - val_accuracy: 0.9834 - val_loss: 0.0499
# Epoch 4/10
# 469/469 - 2s - 4ms/step - accuracy: 0.9843 - loss: 0.0496 - val_accuracy: 0.9856 - val_loss: 0.0406
# Epoch 5/10
# 469/469 - 2s - 4ms/step - accuracy: 0.9865 - loss: 0.0420 - val_accuracy: 0.9861 - val_loss: 0.0383
# Epoch 6/10
# 469/469 - 2s - 4ms/step - accuracy: 0.9886 - loss: 0.0343 - val_accuracy: 0.9885 - val_loss: 0.0343
# Epoch 7/10
# 469/469 - 2s - 4ms/step - accuracy: 0.9896 - loss: 0.0316 - val_accuracy: 0.9870 - val_loss: 0.0419
# Epoch 8/10
# 469/469 - 2s - 4ms/step - accuracy: 0.9913 - loss: 0.0265 - val_accuracy: 0.9862 - val_loss: 0.0418
# Epoch 9/10
# 469/469 - 2s - 4ms/step - accuracy: 0.9924 - loss: 0.0232 - val_accuracy: 0.9877 - val_loss: 0.0384
# Epoch 10/10
# 469/469 - 2s - 5ms/step - accuracy: 0.9934 - loss: 0.0207 - val_accuracy: 0.9875 - val_loss: 0.0365
# 정확률= 98.7500011920929

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dropout,Dense
from tensorflow.keras.optimizers import Adam

(x_train,y_train),(x_test,y_test)=ds.cifar10.load_data()
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

cnn=Sequential()
cnn.add(Conv2D(6,(5,5),padding='same',activation='relu',input_shape=(32,32,3)))
cnn.add(MaxPooling2D(pool_size=(2,2),strides=2))
cnn.add(Conv2D(16,(5,5),padding='valid',activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2),strides=2))
cnn.add(Conv2D(120,(5,5),padding='valid',activation='relu'))
cnn.add(Flatten())
cnn.add(Dense(units=84,activation='relu'))
cnn.add(Dense(units=10,activation='softmax'))

cnn.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
cnn.fit(x_train,y_train,batch_size=128,epochs=10,validation_data=(x_test,y_test),verbose=2)

res=cnn.evaluate(x_test,y_test,verbose=0)
print('정확률=',res[1]*100)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# Epoch 1/10
# 391/391 - 8s - 21ms/step - accuracy: 0.3954 - loss: 1.6602 - val_accuracy: 0.4850 - val_loss: 1.4463
# Epoch 2/10
# 391/391 - 5s - 13ms/step - accuracy: 0.5182 - loss: 1.3412 - val_accuracy: 0.5541 - val_loss: 1.2672
# Epoch 3/10
# 391/391 - 2s - 4ms/step - accuracy: 0.5660 - loss: 1.2185 - val_accuracy: 0.5672 - val_loss: 1.2241
# Epoch 4/10
# 391/391 - 2s - 6ms/step - accuracy: 0.5982 - loss: 1.1366 - val_accuracy: 0.5909 - val_loss: 1.1520
# Epoch 5/10
# 391/391 - 2s - 5ms/step - accuracy: 0.6241 - loss: 1.0652 - val_accuracy: 0.5853 - val_loss: 1.1907
# Epoch 6/10
# 391/391 - 2s - 6ms/step - accuracy: 0.6447 - loss: 1.0101 - val_accuracy: 0.6256 - val_loss: 1.0663
# Epoch 7/10
# 391/391 - 2s - 4ms/step - accuracy: 0.6633 - loss: 0.9587 - val_accuracy: 0.6217 - val_loss: 1.0943
# Epoch 8/10
# 391/391 - 2s - 4ms/step - accuracy: 0.6798 - loss: 0.9136 - val_accuracy: 0.6471 - val_loss: 1.0277
# Epoch 9/10
# 391/391 - 2s - 4ms/step - accuracy: 0.6957 - loss: 0.8714 - val_accuracy: 0.6548 - val_loss: 1.0039
# Epoch 10/10
# 391/391 - 3s - 8ms/step - accuracy: 0.7062 - loss: 0.8388 - val_accuracy: 0.6584 - val_loss: 0.9891
# 정확률= 65.83999991416931

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.optimizers import Adam

(x_train,y_train),(x_test,y_test)=ds.cifar10.load_data()
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

cnn=Sequential()
cnn.add(Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
cnn.add(Conv2D(32,(3,3),activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))
cnn.add(Conv2D(64,(3,3),activation='relu'))
cnn.add(Conv2D(64,(3,3),activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))
cnn.add(Flatten())
cnn.add(Dense(units=512,activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(units=10,activation='softmax'))

# %%
cnn.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist=cnn.fit(x_train,y_train,batch_size=128,epochs=10,validation_data=(x_test,y_test),verbose=2)

res=cnn.evaluate(x_test,y_test,verbose=0)
print('정확률=',res[1]*100)

import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy graph')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'])
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss graph')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'])
plt.grid()
plt.show()
# Out:
# Epoch 1/10
# 391/391 - 15s - 38ms/step - accuracy: 0.3877 - loss: 1.6544 - val_accuracy: 0.5079 - val_loss: 1.3631
# Epoch 2/10
# 391/391 - 4s - 9ms/step - accuracy: 0.5481 - loss: 1.2609 - val_accuracy: 0.6104 - val_loss: 1.0930
# Epoch 3/10
# 391/391 - 5s - 12ms/step - accuracy: 0.6124 - loss: 1.0944 - val_accuracy: 0.6582 - val_loss: 0.9606
# Epoch 4/10
# 391/391 - 5s - 13ms/step - accuracy: 0.6525 - loss: 0.9817 - val_accuracy: 0.6927 - val_loss: 0.8864
# Epoch 5/10
# 391/391 - 5s - 13ms/step - accuracy: 0.6825 - loss: 0.9050 - val_accuracy: 0.7079 - val_loss: 0.8320
# Epoch 6/10
# 391/391 - 3s - 8ms/step - accuracy: 0.7015 - loss: 0.8499 - val_accuracy: 0.7119 - val_loss: 0.8347
# Epoch 7/10
# 391/391 - 3s - 8ms/step - accuracy: 0.7203 - loss: 0.7956 - val_accuracy: 0.7300 - val_loss: 0.7639
# Epoch 8/10
# 391/391 - 4s - 9ms/step - accuracy: 0.7342 - loss: 0.7549 - val_accuracy: 0.7373 - val_loss: 0.7498
# Epoch 9/10
# 391/391 - 3s - 9ms/step - accuracy: 0.7449 - loss: 0.7207 - val_accuracy: 0.7556 - val_loss: 0.6990
# Epoch 10/10
# 391/391 - 5s - 13ms/step - accuracy: 0.7597 - loss: 0.6849 - val_accuracy: 0.7645 - val_loss: 0.6801
# 정확률= 76.45000219345093

# %%
import cv2 as cv
import numpy as np
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input,decode_predictions
from google.colab.patches import cv2_imshow

model=ResNet50(weights='imagenet')

img=cv.imread('/content/drive/MyDrive/rabbit.jpg')
x=np.reshape(cv.resize(img,(224,224)),(1,224,224,3))
x=preprocess_input(x)

preds=model.predict(x)
top5=decode_predictions(preds,top=5)[0]
print('예측 결과:',top5)

for i in range(5):
    cv.putText(img,top5[i][1]+':'+str(top5[i][2]),(10,20+i*20),cv.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),1)

#cv.imshow('Recognition result',img)
cv2_imshow(img)

#cv.waitKey()
#cv.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 예측 결과: [('n02325366', 'wood_rabbit', 0.7427542), ('n02326432', 'hare', 0.24023649), ('n02328150', 'Angora', 0.008815731), ('n01877812', 'wallaby', 0.002689241), ('n02356798', 'fox_squirrel', 0.0012279275)]
# <PIL.Image.Image image mode=RGB size=484x599>
